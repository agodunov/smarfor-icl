# %% [markdown]
# # Find the optimal architecture for the Neural Network

# %% [markdown]
# This piece of code was written by me to find the optimal architecture for the third model, a neural network. As the Neural Network training takes a long time due to complexity I have chosen the Bayesian Optimization (BO) method because it helps to find the model close to the optimal with the minium number of attempts in the space of 188k possible variants of NN.
# Through some experiments outside the scope of this document, I have found that for training the network on a test dataset of 30 features and 6000 samples, I would prefer a fully connected model with no more than 4 hidden layers. An additional series of simple experiments showed that the most preferred activation functions for the network layers are
# $$ ReLU - Sigmoid - Sigmoid - Sigmoid $$

# %% [markdown]
# The architecture in this sense will consist of finding the optimal number of neurons for each hidden layer.
# The criterion for the optimal architecture is chosen relatively voluntaristically - the maximum accuracy of the model on a test samples after 100,000 training epochs with a step of 0.002 on a training data set. The accuracy of the model is measured by L2 norm of future 20 days Moving Average prediction. I also store the accuracy of predicting the market direction on the test data for futher analysis. I assume that if the model shows a good training result under these conditions, then it will be close to optimal and suitable for the final modeling in production.
#
# To limit the search space, I introduce a couple more restrictions:
# 1) The number of network parameters should not exceed the half number of samples, otherwise the network will simply remember them and will be unsuitable due to the large variance on the test data
# 2) My experience of building well-functioning networks shows that the number of neurons in the first layers is usually larger than the subsequent ones.
#
# These two conservative conditions will allow me to somewhat narrow the parameter space and simplify the difficult task. Bayesian Optimization is implemented via Gaussian Process Regressor with Radial Base Function as a kernel. I used extensively GPU to speed up the calculations in one single batch. It took 8 hours of powerful machine to train and compare ~250 models. Here is how:

# %%
# Load required packages
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import time
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# ### Define a few important global constants
#
# *As a seasoned C programmer I don't like any global variables, but I will deviate from this good rule for the sake of task resolution speed*

# %%
Verbose = True # True: print more run-time info, False: less

# %%
MaxNNParameters = 3500 # This is the maximum allowed network parameters. It should be less than the number of test samples

# %%
NumFeatures = 30 # The number of features in input class

# %%
LearningRate = 0.002 # The standard learning rate for NN test
WeightDecay = 1e-8 # The Wait Decay for Adam algorythm to improve convergence
NumEpochs = 100000 # The number of epochs to train NN for evaluation

# %%
# standard precision
np.set_printoptions(precision=8)

# %% [markdown]
# ### Load a dataset for NN training

# %%
ds = pd.read_excel('dataset.xlsx', parse_dates=[0], index_col=0)

# %%
# The last two columns in data set are the real future data to be predicted
X_ = ds.iloc[:,:-2].values
# The last one is a column to be predicted, note this is regression rather than classification problem
y_ = ds.iloc[:,-2].values * 100 # Y Scaler!

# %%
#Split the data into training and testing sets, I use 20% test sample
X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.2)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# With GPU Nvidia 4090 it works much faster:
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = torch.device('cpu')
if Verbose: print(device)
# Out:
# cuda:0

# %%
# Convert numpy arrays to PyTorch tensors
X_train = torch.tensor(X_train_scaled, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
X_test = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

# %% [markdown]
# ### Now build the search space

# %%
space = []
for x1 in range(1,130):
    for x2 in range(1,100):
        for x3 in range(1,100):
            for x4 in range(1,100):
                if 30*x1 + x1 + x1*x2 + x2 + x2*x3 + x3 + x3*x4 + x4 > MaxNNParameters : continue
                if x1 < x2 or x2 < x3 or x3 < x4 : continue
                space.append([x1, x2, x3, x4])

# %%
space = np.array(space)
len(space)
# Out:
# 188547

# %% [markdown]
# ### Define a calss for 4 layered NN

# %%
class Net(nn.Module):
    def __init__(self, x1=50, x2=20, x3=10, x4=2, name=None):
        super(Net, self).__init__()
        if name:
            self.name = name
        self.x1 = x1
        self.x2 = x2
        self.x3 = x3
        self.x4 = x4
        # Define network layers here:
        self.fc1 = nn.Linear(NumFeatures, x1)
        self.fc2 = nn.Linear(x1, x2)
        self.fc3 = nn.Linear(x2, x3)
        self.fc4 = nn.Linear(x3, x4)
        self.fc5 = nn.Linear(x4, 1)    # This is regression problem, so 1 output is enough
        
        # compute the total number of parameters
        total_params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        if Verbose: print(self.name + ': total params:', total_params)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.sigmoid(self.fc2(x))
        x = F.sigmoid(self.fc3(x))
        x = F.sigmoid(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
# Define the program to train NN
def train_model(model, X, y, criterion, optimizer, num_epochs=25, verbose=False):
    start = time.time()
    best_loss = float('inf')
    best_model = model
    
    model.train()
    for epoch in range(num_epochs):

        outputs = model(X)
        loss = criterion(outputs, y)
        optimizer.zero_grad()
        loss.backward()

        if loss.item() < best_loss:
            best_loss = loss.item()
            best_model = model

        optimizer.step()

        if verbose and (epoch+1) % int(num_epochs / 5) == 0:
            print(f'Epoch [{epoch+1:6d}/{num_epochs}], Loss: {loss.item():.8f}')

    model = best_model
    model.eval()
    end = time.time()
    if verbose : print(f'Training accuracy:  {best_loss:.8f}')
    # if verbose: print(f'training accuracy: {best_loss:.8f}')
    #if verbose: print('training time sec', end - start)
    return best_loss

# %%
# Define the accuracy function for NN
# It should be able to hangle GPU
def get_accuracy(net, X, y):
    net.eval()
    with torch.no_grad():
        y_pred = net(X).cpu()
    # Calculate accuracy of direction
    accuracy = accuracy_score(np.sign(y.cpu()), np.sign(y_pred))*100
    if Verbose: print(f'Direction accuracy: {accuracy:.2f}%')
    
#    Calculate confusion matrix
#    conf_matrix = confusion_matrix(np.sign(y.cpu()), np.sign(y_pred))
#    if Verbose: print('Confusion Matrix:')
#    if Verbose: print(conf_matrix)
    return accuracy

# %%
def evaluate(par, X, y, device, verbose=False):
    name = 'NN ' + str(par[0]) + '-' + str(par[1]) + '-' + str(par[2]) + '-' + str(par[3])
    model = Net(name=name, x1=par[0], x2=par[1], x3= par[2], x4=par[3]).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=LearningRate, weight_decay=WeightDecay)
    error_l2 = train_model(model, X, y, criterion, optimizer, num_epochs=NumEpochs, verbose=verbose)
    # accuracy = get_accuracy(model, X_test, y_test)
    accuracy = criterion(model(X_test), y_test).item()
    if verbose : print(f'Testing  accuracy:  {accuracy:.8f}')
    return accuracy, error_l2, model.cpu()

# %%
# Define evaluation lists
accuracy_rates = []
dir_accuracy = []
error_rates = []
models = []

# %% [markdown]
# ### Initiate first samples

# %%
init_idx = np.random.choice(len(space), size=2, replace=False)

# %%
hyperparams = np.concatenate((space[init_idx], np.array([[50, 20, 10, 2]])), axis=0)

# %%
hyperparams
# Out:
# array([[26, 25, 17, 17],
#        [28, 27, 20, 10],
#        [50, 20, 10,  2]])

# %%
# Run preliminary circle to collect few points
for par in hyperparams:
    accuracy, error, model = evaluate(par, X_train, y_train, device, verbose=True)
    accuracy_rates.append(accuracy)
    error_rates.append(error)
    models.append(model)
    dir_accuracy.append(get_accuracy(model.to(device), X_test, y_test))
# Out:
# NN 26-25-17-17: total params: 2247
# Epoch [ 20000/100000], Loss: 0.18826523
# Epoch [ 40000/100000], Loss: 0.13508458
# Epoch [ 60000/100000], Loss: 0.11558980
# Epoch [ 80000/100000], Loss: 0.10436151
# Epoch [100000/100000], Loss: 0.09589542
# Training accuracy:  0.09580736
# Testing  accuracy:  0.87984765
# Direction accuracy: 93.14%
# NN 28-27-20-10: total params: 2432
# Epoch [ 20000/100000], Loss: 0.20629238
# Epoch [ 40000/100000], Loss: 0.14392425
# Epoch [ 60000/100000], Loss: 0.11703361
# Epoch [ 80000/100000], Loss: 0.09935556
# Epoch [100000/100000], Loss: 0.09302331
# Training accuracy:  0.09181925
# Testing  accuracy:  1.07597053
# Direction accuracy: 92.47%
# NN 50-20-10-2: total params: 2805
# Epoch [ 20000/100000], Loss: 0.12951216
# Epoch [ 40000/100000], Loss: 0.10056552
# Epoch [ 60000/100000], Loss: 0.09416066
# Epoch [ 80000/100000], Loss: 0.08965769
# Epoch [100000/100000], Loss: 0.08563521
# Training accuracy:  0.08544391
# Testing  accuracy:  2.08913016
# Direction accuracy: 91.12%

# %% [markdown]
# ## Use Gaussian Process Regressor with Radial Based Function

# %%
# The code to recover calculations from excel file
#df = pd.read_excel('hyperparameters.xlsx')
#hyperparams = df[['x1','x2','x3','x4']].values
#accuracy_rates = list(df['TestAcc'].values)
#error_rates = list(df['TrainEcc'].values)
#dir_accuracy = list(df['DirAcc'].values)

# %%
# Apply workaround with custom optmizer to get rid of max_iter warning
from scipy.optimize import fmin_l_bfgs_b

# Custom optimizer with maxiter set
def custom_optimizer(obj_func, initial_theta, bounds):
    optimized_result = fmin_l_bfgs_b(
        obj_func,
        initial_theta,
        bounds=bounds,
        maxiter=50000  # Increase maxiter as needed
    )
    # fmin_l_bfgs_b returns (optimized_params, min_value, info_dict)
    return optimized_result[0], optimized_result[1]

kernel = RBF(length_scale = 1., length_scale_bounds=(1e-10 , 1e10))

# Create the GaussianProcessRegressor with the custom optimizer
bo_model = GaussianProcessRegressor(
    kernel=kernel,
    alpha=1e-8,
    n_restarts_optimizer=1,
    normalize_y=True,
    optimizer=custom_optimizer
)

# %%
# Do the fixed number of BO iterations
for i in range(1, 250):
    
    bo_model.fit(hyperparams, accuracy_rates)
    # Predict for the grid
    post_mean, post_std = bo_model.predict(space, return_std=True)
     
    # Define acquiring function
    a_fun = post_mean - 1 * post_std 
    # Find the index and minimum value of acquiring function
    i = np.argmin(a_fun)
    print(f'The min of acquiring = {a_fun[i]:.8f}, post_mean = {post_mean[i]:.8f}, post_std = {post_std[i]:.8f}, index {i}')
    #print('post_mean =', post_mean[i],' post_std =', post_std[i])
    #print('the index ', i)
    accuracy, error, model = evaluate(space[i], X_train, y_train, device, verbose=True)
    hyperparams = np.concatenate((hyperparams, space[i].reshape(1,4)), axis=0)
    accuracy_rates.append(accuracy)
    dir_accuracy.append(get_accuracy(model.to(device), X_test, y_test))
    error_rates.append(error)
    models.append(model)
# Out:
# The min of acquiring = 0.64285871, post_mean = 1.06417563, post_std = 0.42131691, index 23226
# NN 26-25-17-16: total params: 2228
# Epoch [ 20000/100000], Loss: 0.21014476
# Epoch [ 40000/100000], Loss: 0.15238474
# Epoch [ 60000/100000], Loss: 0.12571113
# Epoch [ 80000/100000], Loss: 0.11170570
# Epoch [100000/100000], Loss: 0.10280173
# Training accuracy:  0.10278814
# Testing  accuracy:  0.74630129
# Direction accuracy: 93.63%
# The min of acquiring = 0.36124104, post_mean = 0.70609292, post_std = 0.34485187, index 19967
# NN 25-24-15-13: total params: 1996
# Epoch [ 20000/100000], Loss: 0.19587722
# Epoch [ 40000/100000], Loss: 0.15128170
# Epoch [ 60000/100000], Loss: 0.13372713
# Epoch [ 80000/100000], Loss: 0.12316079
# Epoch [100000/100000], Loss: 0.11355854
# Training accuracy:  0.11351389
# Testing  accuracy:  0.77089673
# Direction accuracy: 93.02%
# The min of acquiring = 0.39421265, post_mean = 0.73231638, post_std = 0.33810374, index 17434
# NN 24-24-19-14: total params: 2114
# Epoch [ 20000/100000], Loss: 0.33838496
# Epoch [ 40000/100000], Loss: 0.25772110
# Epoch [ 60000/100000], Loss: 0.20923062
# Epoch [ 80000/100000], Loss: 0.18094794
# Epoch [100000/100000], Loss: 0.16483885
# Training accuracy:  0.16442110
# Testing  accuracy:  0.74455273
# Direction accuracy: 94.43%
# The min of acquiring = 0.39917804, post_mean = 0.75852457, post_std = 0.35934653, index 33655
# NN 29-23-18-14: total params: 2302
# Epoch [ 20000/100000], Loss: 0.24443647
# Epoch [ 40000/100000], Loss: 0.18206133
# Epoch [ 60000/100000], Loss: 0.14927867
# Epoch [ 80000/100000], Loss: 0.12867735
# Epoch [100000/100000], Loss: 0.11535477
# Training accuracy:  0.11349104
# Testing  accuracy:  0.71922898
# Direction accuracy: 93.08%
# The min of acquiring = 0.42277678, post_mean = 0.75089462, post_std = 0.32811784, index 34859
# NN 29-27-15-14: total params: 2368
# Epoch [ 20000/100000], Loss: 0.13016455
# Epoch [ 40000/100000], Loss: 0.10327083
# Epoch [ 60000/100000], Loss: 0.08892129
# Epoch [ 80000/100000], Loss: 0.08104251
# Epoch [100000/100000], Loss: 0.07696591
# Training accuracy:  0.07673435
# Testing  accuracy:  1.02611673
# Direction accuracy: 93.33%
# The min of acquiring = 0.49026889, post_mean = 0.75451078, post_std = 0.26424189, index 22164
# NN 26-21-17-14: total params: 2014
# Epoch [ 20000/100000], Loss: 0.22551960
# Epoch [ 40000/100000], Loss: 0.17262918
# Epoch [ 60000/100000], Loss: 0.14650548
# Epoch [ 80000/100000], Loss: 0.12545730
# Epoch [100000/100000], Loss: 0.11486900
# Training accuracy:  0.11485767
# Testing  accuracy:  0.84755170
# Direction accuracy: 92.84%
# The min of acquiring = 0.50889345, post_mean = 0.73756416, post_std = 0.22867071, index 26880
# NN 27-26-20-15: total params: 2436
# Epoch [ 20000/100000], Loss: 0.18433818
# Epoch [ 40000/100000], Loss: 0.13218918
# Epoch [ 60000/100000], Loss: 0.10797053
# Epoch [ 80000/100000], Loss: 0.09525046
# Epoch [100000/100000], Loss: 0.08726473
# Training accuracy:  0.08706503
# Testing  accuracy:  1.04121017
# Direction accuracy: 91.98%
# The min of acquiring = 0.54256151, post_mean = 0.69295065, post_std = 0.15038914, index 17384
# NN 24-24-16-15: total params: 2015
# Epoch [ 20000/100000], Loss: 0.25356925
# Epoch [ 40000/100000], Loss: 0.18210101
# Epoch [ 60000/100000], Loss: 0.14818965
# Epoch [ 80000/100000], Loss: 0.12824139
# Epoch [100000/100000], Loss: 0.11961309
# Training accuracy:  0.11959919
# Testing  accuracy:  0.77232397
# Direction accuracy: 93.14%
# The min of acquiring = 0.53477129, post_mean = 0.65154345, post_std = 0.11677216, index 26199
# NN 27-24-17-13: total params: 2182
# Epoch [ 20000/100000], Loss: 0.19657949
# Epoch [ 40000/100000], Loss: 0.15081607
# Epoch [ 60000/100000], Loss: 0.13181174
# Epoch [ 80000/100000], Loss: 0.12063763
# Epoch [100000/100000], Loss: 0.11150105
# Training accuracy:  0.11143963
# Testing  accuracy:  1.03651786
# Direction accuracy: 92.90%
# The min of acquiring = 0.44406531, post_mean = 0.72262615, post_std = 0.27856085, index 37898
# NN 30-22-18-16: total params: 2347
# Epoch [ 20000/100000], Loss: 0.16519132
# Epoch [ 40000/100000], Loss: 0.13498552
# Epoch [ 60000/100000], Loss: 0.12195718
# Epoch [ 80000/100000], Loss: 0.11484098
# Epoch [100000/100000], Loss: 0.10696878
# Training accuracy:  0.10694438
# Testing  accuracy:  1.12638974
# Direction accuracy: 91.73%
# The min of acquiring = 0.50994335, post_mean = 0.76330630, post_std = 0.25336295, index 38166
# NN 30-23-19-13: total params: 2373
# Epoch [ 20000/100000], Loss: 0.17377132
# Epoch [ 40000/100000], Loss: 0.13169269
# Epoch [ 60000/100000], Loss: 0.10484415
# Epoch [ 80000/100000], Loss: 0.08909777
# Epoch [100000/100000], Loss: 0.07952736
# Training accuracy:  0.07881118
# Testing  accuracy:  1.11272240
# Direction accuracy: 93.82%
# The min of acquiring = 0.49837154, post_mean = 0.73303927, post_std = 0.23466773, index 20017
# NN 25-24-18-15: total params: 2150
# Epoch [ 20000/100000], Loss: 0.31434134
# Epoch [ 40000/100000], Loss: 0.23571958
# Epoch [ 60000/100000], Loss: 0.19821072
# Epoch [ 80000/100000], Loss: 0.17253648
# Epoch [100000/100000], Loss: 0.14883967
# Training accuracy:  0.14883967
# Testing  accuracy:  0.69592905
# Direction accuracy: 93.26%
# The min of acquiring = 0.48331646, post_mean = 0.71905374, post_std = 0.23573728, index 25942
# NN 27-23-18-15: total params: 2214
# Epoch [ 20000/100000], Loss: 0.20392063
# Epoch [ 40000/100000], Loss: 0.14142026
# Epoch [ 60000/100000], Loss: 0.12060812
# Epoch [ 80000/100000], Loss: 0.10769392
# Epoch [100000/100000], Loss: 0.09866306
# Training accuracy:  0.09843527
# Testing  accuracy:  0.59189785
# Direction accuracy: 94.86%
# The min of acquiring = 0.46363413, post_mean = 0.62428482, post_std = 0.16065070, index 29579
# NN 28-23-17-15: total params: 2229
# Epoch [ 20000/100000], Loss: 0.22224626
# Epoch [ 40000/100000], Loss: 0.15402922
# Epoch [ 60000/100000], Loss: 0.12639326
# Epoch [ 80000/100000], Loss: 0.11173755
# Epoch [100000/100000], Loss: 0.10369687
# Training accuracy:  0.10304409
# Testing  accuracy:  1.07305098
# Direction accuracy: 94.12%
# The min of acquiring = 0.38314772, post_mean = 0.59165412, post_std = 0.20850640, index 25960
# NN 27-23-19-15: total params: 2253
# Epoch [ 20000/100000], Loss: 0.26528877
# Epoch [ 40000/100000], Loss: 0.19664863
# Epoch [ 60000/100000], Loss: 0.16484514
# Epoch [ 80000/100000], Loss: 0.14101350
# Epoch [100000/100000], Loss: 0.12632814
# Training accuracy:  0.12390145
# Testing  accuracy:  0.62465507
# Direction accuracy: 94.18%
# The min of acquiring = 0.41624431, post_mean = 0.57805549, post_std = 0.16181118, index 22666
# NN 26-23-18-15: total params: 2160
# Epoch [ 20000/100000], Loss: 0.22348543
# Epoch [ 40000/100000], Loss: 0.16860376
# Epoch [ 60000/100000], Loss: 0.15100449
# Epoch [ 80000/100000], Loss: 0.13418293
# Epoch [100000/100000], Loss: 0.11881190
# Training accuracy:  0.11872349
# Testing  accuracy:  1.18215680
# Direction accuracy: 91.43%
# The min of acquiring = 0.59186560, post_mean = 0.59189785, post_std = 0.00003225, index 25942
# NN 27-23-18-15: total params: 2214
# Epoch [ 20000/100000], Loss: 0.19050930
# Epoch [ 40000/100000], Loss: 0.14462613
# Epoch [ 60000/100000], Loss: 0.12494563
# Epoch [ 80000/100000], Loss: 0.11129882
# Epoch [100000/100000], Loss: 0.10211452
# Training accuracy:  0.10199918
# Testing  accuracy:  1.42554438
# Direction accuracy: 92.53%
# The min of acquiring = 0.41086531, post_mean = 0.65893990, post_std = 0.24807459, index 29614
# NN 28-23-19-15: total params: 2307
# Epoch [ 20000/100000], Loss: 0.18841134
# Epoch [ 40000/100000], Loss: 0.13626413
# Epoch [ 60000/100000], Loss: 0.11548829
# Epoch [ 80000/100000], Loss: 0.10356976
# Epoch [100000/100000], Loss: 0.09537193
# Training accuracy:  0.09483323
# Testing  accuracy:  0.83502477
# Direction accuracy: 92.77%
# The min of acquiring = 0.44382977, post_mean = 0.68395655, post_std = 0.24012678, index 25979
# NN 27-23-20-15: total params: 2292
# Epoch [ 20000/100000], Loss: 0.20695429
# Epoch [ 40000/100000], Loss: 0.14603014
# Epoch [ 60000/100000], Loss: 0.11957607
# Epoch [ 80000/100000], Loss: 0.10767964
# Epoch [100000/100000], Loss: 0.09650633
# Training accuracy:  0.09604105
# Testing  accuracy:  0.87273675
# Direction accuracy: 93.08%
# The min of acquiring = 0.58374861, post_mean = 0.89355795, post_std = 0.30980934, index 25959
# NN 27-23-19-14: total params: 2232
# Epoch [ 20000/100000], Loss: 0.19562271
# Epoch [ 40000/100000], Loss: 0.13296892
# Epoch [ 60000/100000], Loss: 0.11569143
# Epoch [ 80000/100000], Loss: 0.10100249
# Epoch [100000/100000], Loss: 0.09012498
# Training accuracy:  0.09012498
# Testing  accuracy:  1.06896448
# Direction accuracy: 93.14%
# The min of acquiring = 0.62462397, post_mean = 0.62465507, post_std = 0.00003110, index 25960
# NN 27-23-19-15: total params: 2253
# Epoch [ 20000/100000], Loss: 0.18618529
# Epoch [ 40000/100000], Loss: 0.12158580
# Epoch [ 60000/100000], Loss: 0.09879699
# Epoch [ 80000/100000], Loss: 0.09004293
# Epoch [100000/100000], Loss: 0.08498426
# Training accuracy:  0.08435856
# Testing  accuracy:  0.75639546
# Direction accuracy: 94.37%
# The min of acquiring = 0.58126661, post_mean = 0.87803479, post_std = 0.29676819, index 17417
# NN 24-24-18-15: total params: 2095
# Epoch [ 20000/100000], Loss: 0.27621436
# Epoch [ 40000/100000], Loss: 0.19339354
# Epoch [ 60000/100000], Loss: 0.16564730
# Epoch [ 80000/100000], Loss: 0.15012564
# Epoch [100000/100000], Loss: 0.12777597
# Training accuracy:  0.12763107
# Testing  accuracy:  0.66390544
# Direction accuracy: 93.51%
# The min of acquiring = 0.46478676, post_mean = 0.69779658, post_std = 0.23300982, index 20317
# NN 25-25-18-15: total params: 2194
# Epoch [ 20000/100000], Loss: 0.23152433
# Epoch [ 40000/100000], Loss: 0.16785164
# Epoch [ 60000/100000], Loss: 0.13500698
# Epoch [ 80000/100000], Loss: 0.11529870
# Epoch [100000/100000], Loss: 0.10455427
# Training accuracy:  0.10453807
# Testing  accuracy:  0.91111559
# Direction accuracy: 92.59%
# The min of acquiring = 0.52284394, post_mean = 0.77620054, post_std = 0.25335660, index 17416
# NN 24-24-18-14: total params: 2075
# Epoch [ 20000/100000], Loss: 0.19873634
# Epoch [ 40000/100000], Loss: 0.14144330
# Epoch [ 60000/100000], Loss: 0.12197930
# Epoch [ 80000/100000], Loss: 0.10852606
# Epoch [100000/100000], Loss: 0.09953047
# Training accuracy:  0.09889707
# Testing  accuracy:  1.18883312
# Direction accuracy: 92.90%
# The min of acquiring = 0.65960581, post_mean = 0.95848038, post_std = 0.29887457, index 0
# NN 1-1-1-1: total params: 39
# Epoch [ 20000/100000], Loss: 6.09917879
# Epoch [ 40000/100000], Loss: 6.08005238
# Epoch [ 60000/100000], Loss: 6.07701063
# Epoch [ 80000/100000], Loss: 6.07618284
# Epoch [100000/100000], Loss: 6.07507753
# Training accuracy:  6.07507133
# Testing  accuracy:  7.29060268
# Direction accuracy: 77.77%
# The min of acquiring = -0.23786577, post_mean = 0.78394876, post_std = 1.02181453, index 20001
# NN 25-24-17-16: total params: 2129
# Epoch [ 20000/100000], Loss: 0.21654744
# Epoch [ 40000/100000], Loss: 0.15579885
# Epoch [ 60000/100000], Loss: 0.13269354
# Epoch [ 80000/100000], Loss: 0.11716291
# Epoch [100000/100000], Loss: 0.10894735
# Training accuracy:  0.10728182
# Testing  accuracy:  1.03308749
# Direction accuracy: 94.86%
# The min of acquiring = -0.21400030, post_mean = 0.82490097, post_std = 1.03890127, index 17159
# NN 24-23-19-15: total params: 2091
# Epoch [ 20000/100000], Loss: 0.24561778
# Epoch [ 40000/100000], Loss: 0.16116144
# Epoch [ 60000/100000], Loss: 0.13694066
# Epoch [ 80000/100000], Loss: 0.12005775
# Epoch [100000/100000], Loss: 0.10776462
# Training accuracy:  0.10767850
# Testing  accuracy:  0.90250438
# Direction accuracy: 93.75%
# The min of acquiring = -0.15931145, post_mean = 0.90527209, post_std = 1.06458353, index 20036
# NN 25-24-19-16: total params: 2211
# Epoch [ 20000/100000], Loss: 0.27934611
# Epoch [ 40000/100000], Loss: 0.19985993
# Epoch [ 60000/100000], Loss: 0.15959512
# Epoch [ 80000/100000], Loss: 0.13510048
# Epoch [100000/100000], Loss: 0.11774561
# Training accuracy:  0.11774561
# Testing  accuracy:  0.61264765
# Direction accuracy: 93.14%
# The min of acquiring = -0.18999530, post_mean = 0.84424291, post_std = 1.03423821, index 20054
# NN 25-24-20-15: total params: 2230
# Epoch [ 20000/100000], Loss: 0.25368413
# Epoch [ 40000/100000], Loss: 0.19357331
# Epoch [ 60000/100000], Loss: 0.16024852
# Epoch [ 80000/100000], Loss: 0.13832222
# Epoch [100000/100000], Loss: 0.12594150
# Training accuracy:  0.12568361
# Testing  accuracy:  0.66885018
# Direction accuracy: 94.67%
# The min of acquiring = -0.17248722, post_mean = 0.85803290, post_std = 1.03052012, index 26237
# NN 27-24-19-16: total params: 2321
# Epoch [ 20000/100000], Loss: 0.32392836
# Epoch [ 40000/100000], Loss: 0.24430431
# Epoch [ 60000/100000], Loss: 0.21649799
# Epoch [ 80000/100000], Loss: 0.19216211
# Epoch [100000/100000], Loss: 0.18222801
# Training accuracy:  0.17350174
# Testing  accuracy:  0.75917673
# Direction accuracy: 93.51%
# The min of acquiring = -0.56225243, post_mean = 0.29552366, post_std = 0.85777609, index 25213
# NN 27-20-16-13: total params: 1968
# Epoch [ 20000/100000], Loss: 0.26249522
# Epoch [ 40000/100000], Loss: 0.19365622
# Epoch [ 60000/100000], Loss: 0.16693875
# Epoch [ 80000/100000], Loss: 0.15307435
# Epoch [100000/100000], Loss: 0.14108974
# Training accuracy:  0.14086233
# Testing  accuracy:  0.80624115
# Direction accuracy: 93.26%
# The min of acquiring = -0.34845817, post_mean = 0.66134659, post_std = 1.00980477, index 25058
# NN 27-19-18-15: total params: 2030
# Epoch [ 20000/100000], Loss: 0.20051752
# Epoch [ 40000/100000], Loss: 0.15775113
# Epoch [ 60000/100000], Loss: 0.14641841
# Epoch [ 80000/100000], Loss: 0.13714267
# Epoch [100000/100000], Loss: 0.13037281
# Training accuracy:  0.12924969
# Testing  accuracy:  1.09419179
# Direction accuracy: 91.86%
# The min of acquiring = -0.27821460, post_mean = 0.75954315, post_std = 1.03775775, index 16398
# NN 24-20-15-14: total params: 1798
# Epoch [ 20000/100000], Loss: 0.24581572
# Epoch [ 40000/100000], Loss: 0.19502057
# Epoch [ 60000/100000], Loss: 0.16931646
# Epoch [ 80000/100000], Loss: 0.15223934
# Epoch [100000/100000], Loss: 0.14213671
# Training accuracy:  0.14127634
# Testing  accuracy:  1.02884686
# Direction accuracy: 93.02%
# The min of acquiring = -0.13610630, post_mean = 0.73023960, post_std = 0.86634589, index 26811
# NN 27-26-16-16: total params: 2286
# Epoch [ 20000/100000], Loss: 0.18985134
# Epoch [ 40000/100000], Loss: 0.14291854
# Epoch [ 60000/100000], Loss: 0.12232424
# Epoch [ 80000/100000], Loss: 0.10583432
# Epoch [100000/100000], Loss: 0.09663144
# Training accuracy:  0.09655042
# Testing  accuracy:  1.00841165
# Direction accuracy: 94.24%
# The min of acquiring = -0.24330080, post_mean = 0.66791779, post_std = 0.91121859, index 38391
# NN 30-24-16-13: total params: 2309
# Epoch [ 20000/100000], Loss: 0.15739930
# Epoch [ 40000/100000], Loss: 0.12291487
# Epoch [ 60000/100000], Loss: 0.10865863
# Epoch [ 80000/100000], Loss: 0.10154534
# Epoch [100000/100000], Loss: 0.09313481
# Training accuracy:  0.09285148
# Testing  accuracy:  1.08302641
# Direction accuracy: 92.16%
# The min of acquiring = -0.13027155, post_mean = 0.75579586, post_std = 0.88606741, index 14778
# NN 23-23-14-14: total params: 1826
# Epoch [ 20000/100000], Loss: 0.18363842
# Epoch [ 40000/100000], Loss: 0.15379311
# Epoch [ 60000/100000], Loss: 0.14120933
# Epoch [ 80000/100000], Loss: 0.13133512
# Epoch [100000/100000], Loss: 0.12483507
# Training accuracy:  0.12300190
# Testing  accuracy:  0.77371848
# Direction accuracy: 92.96%
# The min of acquiring = -0.08539989, post_mean = 0.81179344, post_std = 0.89719333, index 19027
# NN 25-20-17-12: total params: 1881
# Epoch [ 20000/100000], Loss: 0.26553082
# Epoch [ 40000/100000], Loss: 0.19182990
# Epoch [ 60000/100000], Loss: 0.16725345
# Epoch [ 80000/100000], Loss: 0.15336038
# Epoch [100000/100000], Loss: 0.14173187
# Training accuracy:  0.14161897
# Testing  accuracy:  0.87288243
# Direction accuracy: 94.00%
# The min of acquiring = -0.05785730, post_mean = 0.84641029, post_std = 0.90426759, index 17092
# NN 24-23-15-14: total params: 1918
# Epoch [ 20000/100000], Loss: 0.23245898
# Epoch [ 40000/100000], Loss: 0.16976556
# Epoch [ 60000/100000], Loss: 0.14322768
# Epoch [ 80000/100000], Loss: 0.12968341
# Epoch [100000/100000], Loss: 0.11501146
# Training accuracy:  0.11474948
# Testing  accuracy:  0.75289363
# Direction accuracy: 94.00%
# The min of acquiring = -0.04234630, post_mean = 0.86811316, post_std = 0.91045945, index 17471
# NN 24-24-21-12: total params: 2146
# Epoch [ 20000/100000], Loss: 0.25084171
# Epoch [ 40000/100000], Loss: 0.18539864
# Epoch [ 60000/100000], Loss: 0.15039593
# Epoch [ 80000/100000], Loss: 0.12850505
# Epoch [100000/100000], Loss: 0.11108870
# Training accuracy:  0.11106250
# Testing  accuracy:  0.48949999
# Direction accuracy: 94.67%
# The min of acquiring = -0.05741162, post_mean = 0.77799307, post_std = 0.83540469, index 14917
# NN 23-23-22-13: total params: 2106
# Epoch [ 20000/100000], Loss: 0.34411129
# Epoch [ 40000/100000], Loss: 0.25449860
# Epoch [ 60000/100000], Loss: 0.20314196
# Epoch [ 80000/100000], Loss: 0.16928619
# Epoch [100000/100000], Loss: 0.14541654
# Training accuracy:  0.14506358
# Testing  accuracy:  0.76885456
# Direction accuracy: 93.57%
# The min of acquiring = -0.03334550, post_mean = 0.88993054, post_std = 0.92327604, index 14893
# NN 23-23-21-10: total params: 2000
# Epoch [ 20000/100000], Loss: 0.20308349
# Epoch [ 40000/100000], Loss: 0.13695635
# Epoch [ 60000/100000], Loss: 0.11828724
# Epoch [ 80000/100000], Loss: 0.10680693
# Epoch [100000/100000], Loss: 0.10189636
# Training accuracy:  0.10185643
# Testing  accuracy:  1.05449474
# Direction accuracy: 92.28%
# The min of acquiring = -0.00873540, post_mean = 0.87546021, post_std = 0.88419561, index 20414
# NN 25-25-23-12: total params: 2324
# Epoch [ 20000/100000], Loss: 0.22448795
# Epoch [ 40000/100000], Loss: 0.16355373
# Epoch [ 60000/100000], Loss: 0.13605358
# Epoch [ 80000/100000], Loss: 0.11832711
# Epoch [100000/100000], Loss: 0.10611960
# Training accuracy:  0.10606465
# Testing  accuracy:  0.77419597
# Direction accuracy: 95.35%
# The min of acquiring = -0.00100047, post_mean = 0.85965642, post_std = 0.86065689, index 37647
# NN 30-21-17-13: total params: 2203
# Epoch [ 20000/100000], Loss: 0.22563428
# Epoch [ 40000/100000], Loss: 0.16730592
# Epoch [ 60000/100000], Loss: 0.13460222
# Epoch [ 80000/100000], Loss: 0.11794648
# Epoch [100000/100000], Loss: 0.10078953
# Training accuracy:  0.10025801
# Testing  accuracy:  0.94534475
# Direction accuracy: 92.96%
# The min of acquiring = 0.00558197, post_mean = 0.69674344, post_std = 0.69116147, index 20254
# NN 25-25-14-14: total params: 2014
# Epoch [ 20000/100000], Loss: 0.21621285
# Epoch [ 40000/100000], Loss: 0.16067339
# Epoch [ 60000/100000], Loss: 0.13122471
# Epoch [ 80000/100000], Loss: 0.11963864
# Epoch [100000/100000], Loss: 0.11038615
# Training accuracy:  0.11036193
# Testing  accuracy:  0.62458545
# Direction accuracy: 93.33%
# The min of acquiring = 0.01916681, post_mean = 0.86655483, post_std = 0.84738802, index 22589
# NN 26-23-13-13: total params: 1935
# Epoch [ 20000/100000], Loss: 0.28898922
# Epoch [ 40000/100000], Loss: 0.23396233
# Epoch [ 60000/100000], Loss: 0.20243835
# Epoch [ 80000/100000], Loss: 0.17814489
# Epoch [100000/100000], Loss: 0.16600077
# Training accuracy:  0.16478351
# Testing  accuracy:  0.68946153
# Direction accuracy: 92.28%
# The min of acquiring = 0.00897922, post_mean = 0.90227741, post_std = 0.89329818, index 26452
# NN 27-25-14-11: total params: 2078
# Epoch [ 20000/100000], Loss: 0.23848903
# Epoch [ 40000/100000], Loss: 0.16337720
# Epoch [ 60000/100000], Loss: 0.13896132
# Epoch [ 80000/100000], Loss: 0.12291965
# Epoch [100000/100000], Loss: 0.11026574
# Training accuracy:  0.10976564
# Testing  accuracy:  0.84926701
# Direction accuracy: 93.45%
# The min of acquiring = 0.04160264, post_mean = 0.94991800, post_std = 0.90831536, index 31303
# NN 28-28-22-14: total params: 2655
# Epoch [ 20000/100000], Loss: 0.19631146
# Epoch [ 40000/100000], Loss: 0.14179441
# Epoch [ 60000/100000], Loss: 0.11237765
# Epoch [ 80000/100000], Loss: 0.09798158
# Epoch [100000/100000], Loss: 0.08766129
# Training accuracy:  0.08718837
# Testing  accuracy:  0.89616728
# Direction accuracy: 93.26%
# The min of acquiring = 0.05259470, post_mean = 0.88582111, post_std = 0.83322641, index 20227
# NN 25-25-12-12: total params: 1906
# Epoch [ 20000/100000], Loss: 0.17348991
# Epoch [ 40000/100000], Loss: 0.14070623
# Epoch [ 60000/100000], Loss: 0.12659319
# Epoch [ 80000/100000], Loss: 0.11936317
# Epoch [100000/100000], Loss: 0.11380761
# Training accuracy:  0.11380404
# Testing  accuracy:  1.41087699
# Direction accuracy: 93.75%
# The min of acquiring = 0.02926587, post_mean = 0.77012885, post_std = 0.74086298, index 25638
# NN 27-22-15-12: total params: 2003
# Epoch [ 20000/100000], Loss: 0.17881866
# Epoch [ 40000/100000], Loss: 0.13842070
# Epoch [ 60000/100000], Loss: 0.12517712
# Epoch [ 80000/100000], Loss: 0.11285869
# Epoch [100000/100000], Loss: 0.10294600
# Training accuracy:  0.10291523
# Testing  accuracy:  1.25281429
# Direction accuracy: 93.08%
# The min of acquiring = 0.07857292, post_mean = 0.94092249, post_std = 0.86234958, index 30811
# NN 28-27-16-11: total params: 2298
# Epoch [ 20000/100000], Loss: 0.17577986
# Epoch [ 40000/100000], Loss: 0.13916886
# Epoch [ 60000/100000], Loss: 0.11338428
# Epoch [ 80000/100000], Loss: 0.09990583
# Epoch [100000/100000], Loss: 0.08645902
# Training accuracy:  0.08644488
# Testing  accuracy:  1.15831876
# Direction accuracy: 94.30%
# The min of acquiring = 0.08177917, post_mean = 0.74890490, post_std = 0.66712573, index 26155
# NN 27-24-14-14: total params: 2084
# Epoch [ 20000/100000], Loss: 0.23937680
# Epoch [ 40000/100000], Loss: 0.16777439
# Epoch [ 60000/100000], Loss: 0.13782211
# Epoch [ 80000/100000], Loss: 0.12367963
# Epoch [100000/100000], Loss: 0.11201592
# Training accuracy:  0.11196505
# Testing  accuracy:  0.81550449
# Direction accuracy: 94.06%
# The min of acquiring = 0.10449088, post_mean = 0.89673619, post_std = 0.79224532, index 20369
# NN 25-25-21-10: total params: 2202
# Epoch [ 20000/100000], Loss: 0.15524478
# Epoch [ 40000/100000], Loss: 0.11389027
# Epoch [ 60000/100000], Loss: 0.10006978
# Epoch [ 80000/100000], Loss: 0.09321555
# Epoch [100000/100000], Loss: 0.08827586
# Training accuracy:  0.08810058
# Testing  accuracy:  1.25984156
# Direction accuracy: 93.20%
# The min of acquiring = 0.11977761, post_mean = 0.77398061, post_std = 0.65420300, index 18839
# NN 25-19-17-14: total params: 1876
# Epoch [ 20000/100000], Loss: 0.23869026
# Epoch [ 40000/100000], Loss: 0.18362990
# Epoch [ 60000/100000], Loss: 0.15746558
# Epoch [ 80000/100000], Loss: 0.14733446
# Epoch [100000/100000], Loss: 0.13795456
# Training accuracy:  0.13727246
# Testing  accuracy:  0.95418513
# Direction accuracy: 94.30%
# The min of acquiring = 0.13465343, post_mean = 0.99310657, post_std = 0.85845313, index 35730
# NN 29-29-20-16: total params: 2722
# Epoch [ 20000/100000], Loss: 0.22439380
# Epoch [ 40000/100000], Loss: 0.15971392
# Epoch [ 60000/100000], Loss: 0.15455692
# Epoch [ 80000/100000], Loss: 0.10527270
# Epoch [100000/100000], Loss: 0.09298325
# Training accuracy:  0.09147432
# Testing  accuracy:  0.60456932
# Direction accuracy: 94.37%
# The min of acquiring = 0.05935851, post_mean = 0.84131630, post_std = 0.78195778, index 35303
# NN 29-28-19-14: total params: 2585
# Epoch [ 20000/100000], Loss: 0.15505137
# Epoch [ 40000/100000], Loss: 0.11417617
# Epoch [ 60000/100000], Loss: 0.09728315
# Epoch [ 80000/100000], Loss: 0.08791716
# Epoch [100000/100000], Loss: 0.08198942
# Training accuracy:  0.08193154
# Testing  accuracy:  0.95198321
# Direction accuracy: 93.14%
# The min of acquiring = 0.06330892, post_mean = 0.77111048, post_std = 0.70780156, index 31285
# NN 28-28-21-17: total params: 2681
# Epoch [ 20000/100000], Loss: 0.17985673
# Epoch [ 40000/100000], Loss: 0.13353761
# Epoch [ 60000/100000], Loss: 0.10978303
# Epoch [ 80000/100000], Loss: 0.09298407
# Epoch [100000/100000], Loss: 0.08249300
# Training accuracy:  0.08243403
# Testing  accuracy:  0.69793051
# Direction accuracy: 93.88%
# The min of acquiring = 0.07188862, post_mean = 0.82408001, post_std = 0.75219139, index 40226
# NN 30-29-20-18: total params: 2826
# Epoch [ 20000/100000], Loss: 0.20417386
# Epoch [ 40000/100000], Loss: 0.13939475
# Epoch [ 60000/100000], Loss: 0.11337613
# Epoch [ 80000/100000], Loss: 0.09661098
# Epoch [100000/100000], Loss: 0.08627334
# Training accuracy:  0.08460542
# Testing  accuracy:  0.65070099
# Direction accuracy: 94.37%
# The min of acquiring = 0.05429566, post_mean = 0.83246014, post_std = 0.77816448, index 40698
# NN 30-30-22-17: total params: 2951
# Epoch [ 20000/100000], Loss: 0.20682141
# Epoch [ 40000/100000], Loss: 0.14484036
# Epoch [ 60000/100000], Loss: 0.12219709
# Epoch [ 80000/100000], Loss: 0.10615311
# Epoch [100000/100000], Loss: 0.09848914
# Training accuracy:  0.09514776
# Testing  accuracy:  0.48846206
# Direction accuracy: 94.18%
# The min of acquiring = 0.00027305, post_mean = 0.66583222, post_std = 0.66555917, index 45186
# NN 31-29-21-16: total params: 2888
# Epoch [ 20000/100000], Loss: 0.18720452
# Epoch [ 40000/100000], Loss: 0.13861220
# Epoch [ 60000/100000], Loss: 0.11447401
# Epoch [ 80000/100000], Loss: 0.10117089
# Epoch [100000/100000], Loss: 0.08783860
# Training accuracy:  0.08780415
# Testing  accuracy:  0.77610821
# Direction accuracy: 93.39%
# The min of acquiring = 0.04081824, post_mean = 0.80652907, post_std = 0.76571083, index 40290
# NN 30-29-23-19: total params: 2995
# Epoch [ 20000/100000], Loss: 0.14815998
# Epoch [ 40000/100000], Loss: 0.10695746
# Epoch [ 60000/100000], Loss: 0.08754351
# Epoch [ 80000/100000], Loss: 0.07342092
# Epoch [100000/100000], Loss: 0.06631831
# Training accuracy:  0.06628232
# Testing  accuracy:  0.88697112
# Direction accuracy: 94.18%
# The min of acquiring = 0.04612628, post_mean = 0.72534124, post_std = 0.67921495, index 46059
# NN 31-31-21-18: total params: 3040
# Epoch [ 20000/100000], Loss: 0.14375438
# Epoch [ 40000/100000], Loss: 0.10288635
# Epoch [ 60000/100000], Loss: 0.08228409
# Epoch [ 80000/100000], Loss: 0.06992324
# Epoch [100000/100000], Loss: 0.06131219
# Training accuracy:  0.06129716
# Testing  accuracy:  0.92361987
# Direction accuracy: 93.75%
# The min of acquiring = -0.07174241, post_mean = 0.61624979, post_std = 0.68799220, index 35751
# NN 29-29-21-17: total params: 2791
# Epoch [ 20000/100000], Loss: 0.22606428
# Epoch [ 40000/100000], Loss: 0.16227420
# Epoch [ 60000/100000], Loss: 0.13264312
# Epoch [ 80000/100000], Loss: 0.11530632
# Epoch [100000/100000], Loss: 0.10640617
# Training accuracy:  0.10440415
# Testing  accuracy:  0.61847633
# Direction accuracy: 93.75%
# The min of acquiring = -0.01260975, post_mean = 0.68341303, post_std = 0.69602278, index 40742
# NN 30-30-24-16: total params: 3021
# Epoch [ 20000/100000], Loss: 0.13585772
# Epoch [ 40000/100000], Loss: 0.09582945
# Epoch [ 60000/100000], Loss: 0.08784431
# Epoch [ 80000/100000], Loss: 0.06444193
# Epoch [100000/100000], Loss: 0.05610875
# Training accuracy:  0.05608086
# Testing  accuracy:  0.75858992
# Direction accuracy: 93.88%
# The min of acquiring = 0.09432100, post_mean = 0.79555143, post_std = 0.70123043, index 46077
# NN 31-31-22-15: total params: 3018
# Epoch [ 20000/100000], Loss: 0.18449919
# Epoch [ 40000/100000], Loss: 0.12596118
# Epoch [ 60000/100000], Loss: 0.10139263
# Epoch [ 80000/100000], Loss: 0.08304638
# Epoch [100000/100000], Loss: 0.07217921
# Training accuracy:  0.07202009
# Testing  accuracy:  0.85941923
# Direction accuracy: 93.33%
# The min of acquiring = 0.10089328, post_mean = 0.80830139, post_std = 0.70740810, index 40620
# NN 30-30-18-17: total params: 2759
# Epoch [ 20000/100000], Loss: 0.24210973
# Epoch [ 40000/100000], Loss: 0.18724848
# Epoch [ 60000/100000], Loss: 0.15541203
# Epoch [ 80000/100000], Loss: 0.14051434
# Epoch [100000/100000], Loss: 0.14829816
# Training accuracy:  0.12888023
# Testing  accuracy:  0.76060522
# Direction accuracy: 93.63%
# The min of acquiring = 0.10882212, post_mean = 0.76455284, post_std = 0.65573072, index 31247
# NN 28-28-19-18: total params: 2610
# Epoch [ 20000/100000], Loss: 0.21456999
# Epoch [ 40000/100000], Loss: 0.14765786
# Epoch [ 60000/100000], Loss: 0.12179130
# Epoch [ 80000/100000], Loss: 0.10538601
# Epoch [100000/100000], Loss: 0.09299076
# Training accuracy:  0.09261411
# Testing  accuracy:  0.71295238
# Direction accuracy: 94.43%
# The min of acquiring = 0.13269387, post_mean = 0.89823806, post_std = 0.76554419, index 44347
# NN 31-27-18-18: total params: 2690
# Epoch [ 20000/100000], Loss: 0.23981352
# Epoch [ 40000/100000], Loss: 0.17983942
# Epoch [ 60000/100000], Loss: 0.14852583
# Epoch [ 80000/100000], Loss: 0.12970789
# Epoch [100000/100000], Loss: 0.11872400
# Training accuracy:  0.11870620
# Testing  accuracy:  0.95198637
# Direction accuracy: 93.33%
# The min of acquiring = 0.15044372, post_mean = 0.80080161, post_std = 0.65035789, index 51034
# NN 32-30-23-17: total params: 3121
# Epoch [ 20000/100000], Loss: 0.13790260
# Epoch [ 40000/100000], Loss: 0.09463472
# Epoch [ 60000/100000], Loss: 0.07906130
# Epoch [ 80000/100000], Loss: 0.06870127
# Epoch [100000/100000], Loss: 0.06690976
# Training accuracy:  0.06218562
# Testing  accuracy:  0.86358809
# Direction accuracy: 92.59%
# The min of acquiring = 0.17342260, post_mean = 0.89775744, post_std = 0.72433484, index 34950
# NN 29-27-20-20: total params: 2710
# Epoch [ 20000/100000], Loss: 0.26524729
# Epoch [ 40000/100000], Loss: 0.20657071
# Epoch [ 60000/100000], Loss: 0.18305831
# Epoch [ 80000/100000], Loss: 0.15820894
# Epoch [100000/100000], Loss: 0.15106605
# Training accuracy:  0.13959187
# Testing  accuracy:  0.72527015
# Direction accuracy: 94.00%
# The min of acquiring = 0.16287933, post_mean = 0.90846137, post_std = 0.74558204, index 27277
# NN 27-27-22-20: total params: 2690
# Epoch [ 20000/100000], Loss: 0.33474389
# Epoch [ 40000/100000], Loss: 0.25454324
# Epoch [ 60000/100000], Loss: 0.21651424
# Epoch [ 80000/100000], Loss: 0.18026611
# Epoch [100000/100000], Loss: 0.15481456
# Training accuracy:  0.15434879
# Testing  accuracy:  0.76018935
# Direction accuracy: 93.88%
# The min of acquiring = 0.16310741, post_mean = 0.90823531, post_std = 0.74512790, index 34316
# NN 29-25-22-21: total params: 2726
# Epoch [ 20000/100000], Loss: 0.24064544
# Epoch [ 40000/100000], Loss: 0.16882086
# Epoch [ 60000/100000], Loss: 0.12796624
# Epoch [ 80000/100000], Loss: 0.10718571
# Epoch [100000/100000], Loss: 0.09598049
# Training accuracy:  0.08873496
# Testing  accuracy:  0.68509954
# Direction accuracy: 93.02%
# The min of acquiring = 0.14431058, post_mean = 0.81540207, post_std = 0.67109149, index 34993
# NN 29-27-22-22: total params: 2854
# Epoch [ 20000/100000], Loss: 0.20433961
# Epoch [ 40000/100000], Loss: 0.15408076
# Epoch [ 60000/100000], Loss: 0.12965035
# Epoch [ 80000/100000], Loss: 0.11141893
# Epoch [100000/100000], Loss: 0.09826503
# Training accuracy:  0.09764075
# Testing  accuracy:  0.73415661
# Direction accuracy: 93.94%
# The min of acquiring = 0.14494637, post_mean = 0.84706721, post_std = 0.70212084, index 26625
# NN 27-25-23-22: total params: 2686
# Epoch [ 20000/100000], Loss: 0.25878537
# Epoch [ 40000/100000], Loss: 0.18188895
# Epoch [ 60000/100000], Loss: 0.14603895
# Epoch [ 80000/100000], Loss: 0.12462943
# Epoch [100000/100000], Loss: 0.11157735
# Training accuracy:  0.11156941
# Testing  accuracy:  0.83244669
# Direction accuracy: 93.75%
# The min of acquiring = 0.16190849, post_mean = 0.91086374, post_std = 0.74895525, index 49439
# NN 32-26-21-21: total params: 2901
# Epoch [ 20000/100000], Loss: 0.13754448
# Epoch [ 40000/100000], Loss: 0.09696309
# Epoch [ 60000/100000], Loss: 0.08204643
# Epoch [ 80000/100000], Loss: 0.07586145
# Epoch [100000/100000], Loss: 0.07083052
# Training accuracy:  0.06990185
# Testing  accuracy:  1.23093843
# Direction accuracy: 92.47%
# The min of acquiring = 0.16805819, post_mean = 0.85761227, post_std = 0.68955408, index 34685
# NN 29-26-24-20: total params: 2848
# Epoch [ 20000/100000], Loss: 0.21932918
# Epoch [ 40000/100000], Loss: 0.16065858
# Epoch [ 60000/100000], Loss: 0.13551293
# Epoch [ 80000/100000], Loss: 0.11764889
# Epoch [100000/100000], Loss: 0.10305056
# Training accuracy:  0.10250482
# Testing  accuracy:  0.74737972
# Direction accuracy: 93.63%
# The min of acquiring = 0.16955230, post_mean = 0.89681806, post_std = 0.72726576, index 38857
# NN 30-25-24-23: total params: 2928
# Epoch [ 20000/100000], Loss: 0.17558280
# Epoch [ 40000/100000], Loss: 0.11955070
# Epoch [ 60000/100000], Loss: 0.09652759
# Epoch [ 80000/100000], Loss: 0.08522473
# Epoch [100000/100000], Loss: 0.07657278
# Training accuracy:  0.07653830
# Testing  accuracy:  0.63539201
# Direction accuracy: 93.69%
# The min of acquiring = 0.13857497, post_mean = 0.82325724, post_std = 0.68468227, index 35063
# NN 29-27-25-23: total params: 3031
# Epoch [ 20000/100000], Loss: 0.22676899
# Epoch [ 40000/100000], Loss: 0.18642105
# Epoch [ 60000/100000], Loss: 0.13337855
# Epoch [ 80000/100000], Loss: 0.11207062
# Epoch [100000/100000], Loss: 0.09545030
# Training accuracy:  0.09427639
# Testing  accuracy:  0.83028531
# Direction accuracy: 92.71%
# The min of acquiring = 0.01379791, post_mean = 0.63997208, post_std = 0.62617417, index 17452
# NN 24-24-20-13: total params: 2131
# Epoch [ 20000/100000], Loss: 0.22623490
# Epoch [ 40000/100000], Loss: 0.16971000
# Epoch [ 60000/100000], Loss: 0.14704132
# Epoch [ 80000/100000], Loss: 0.13126457
# Epoch [100000/100000], Loss: 0.11907025
# Training accuracy:  0.11873709
# Testing  accuracy:  1.03933299
# Direction accuracy: 92.71%
# The min of acquiring = 0.00015615, post_mean = 0.55325350, post_std = 0.55309735, index 17492
# NN 24-24-22-12: total params: 2183
# Epoch [ 20000/100000], Loss: 0.24594684
# Epoch [ 40000/100000], Loss: 0.17593217
# Epoch [ 60000/100000], Loss: 0.14015514
# Epoch [ 80000/100000], Loss: 0.12348095
# Epoch [100000/100000], Loss: 0.11072013
# Training accuracy:  0.11055759
# Testing  accuracy:  0.82037944
# Direction accuracy: 93.45%
# The min of acquiring = 0.06229228, post_mean = 0.68683840, post_std = 0.62454612, index 40676
# NN 30-30-21-16: total params: 2880
# Epoch [ 20000/100000], Loss: 0.25961244
# Epoch [ 40000/100000], Loss: 0.19713272
# Epoch [ 60000/100000], Loss: 0.15995000
# Epoch [ 80000/100000], Loss: 0.14068633
# Epoch [100000/100000], Loss: 0.12424610
# Training accuracy:  0.12366804
# Testing  accuracy:  0.87034428
# Direction accuracy: 93.02%
# The min of acquiring = 0.05041467, post_mean = 0.68268868, post_std = 0.63227402, index 23688
# NN 26-26-24-13: total params: 2495
# Epoch [ 20000/100000], Loss: 0.21264262
# Epoch [ 40000/100000], Loss: 0.13957143
# Epoch [ 60000/100000], Loss: 0.10755284
# Epoch [ 80000/100000], Loss: 0.09000540
# Epoch [100000/100000], Loss: 0.08696630
# Training accuracy:  0.07768955
# Testing  accuracy:  0.77069581
# Direction accuracy: 93.26%
# The min of acquiring = 0.11101430, post_mean = 0.69034986, post_std = 0.57933555, index 19794
# NN 25-23-21-11: total params: 2131
# Epoch [ 20000/100000], Loss: 0.19938207
# Epoch [ 40000/100000], Loss: 0.15090629
# Epoch [ 60000/100000], Loss: 0.12760232
# Epoch [ 80000/100000], Loss: 0.11039008
# Epoch [100000/100000], Loss: 0.10147773
# Training accuracy:  0.10099718
# Testing  accuracy:  1.51482332
# Direction accuracy: 93.02%
# The min of acquiring = 0.11793378, post_mean = 0.74203468, post_std = 0.62410090, index 12618
# NN 22-22-21-12: total params: 1948
# Epoch [ 20000/100000], Loss: 0.16949092
# Epoch [ 40000/100000], Loss: 0.12936108
# Epoch [ 60000/100000], Loss: 0.10848819
# Epoch [ 80000/100000], Loss: 0.10175531
# Epoch [100000/100000], Loss: 0.09567642
# Training accuracy:  0.09560917
# Testing  accuracy:  0.92089623
# Direction accuracy: 93.88%
# The min of acquiring = 0.13287534, post_mean = 0.71457387, post_std = 0.58169853, index 23642
# NN 26-26-22-12: total params: 2391
# Epoch [ 20000/100000], Loss: 0.15643442
# Epoch [ 40000/100000], Loss: 0.10191235
# Epoch [ 60000/100000], Loss: 0.08377820
# Epoch [ 80000/100000], Loss: 0.07276502
# Epoch [100000/100000], Loss: 0.06738040
# Training accuracy:  0.06680741
# Testing  accuracy:  0.82617486
# Direction accuracy: 94.18%
# The min of acquiring = 0.14459618, post_mean = 0.75598821, post_std = 0.61139203, index 39441
# NN 30-27-20-17: total params: 2702
# Epoch [ 20000/100000], Loss: 0.24496691
# Epoch [ 40000/100000], Loss: 0.18826440
# Epoch [ 60000/100000], Loss: 0.16713199
# Epoch [ 80000/100000], Loss: 0.14211909
# Epoch [100000/100000], Loss: 0.12468550
# Training accuracy:  0.12443147
# Testing  accuracy:  0.74189025
# Direction accuracy: 93.20%
# The min of acquiring = 0.15137115, post_mean = 0.81980192, post_std = 0.66843077, index 23385
# NN 26-25-25-11: total params: 2429
# Epoch [ 20000/100000], Loss: 0.19808657
# Epoch [ 40000/100000], Loss: 0.12744752
# Epoch [ 60000/100000], Loss: 0.10445378
# Epoch [ 80000/100000], Loss: 0.09152809
# Epoch [100000/100000], Loss: 0.08235501
# Training accuracy:  0.08216164
# Testing  accuracy:  0.94937658
# Direction accuracy: 92.77%
# The min of acquiring = 0.15854742, post_mean = 0.76191391, post_std = 0.60336650, index 39882
# NN 30-28-23-17: total params: 2891
# Epoch [ 20000/100000], Loss: 0.16573802
# Epoch [ 40000/100000], Loss: 0.11110436
# Epoch [ 60000/100000], Loss: 0.08963273
# Epoch [ 80000/100000], Loss: 0.07426748
# Epoch [100000/100000], Loss: 0.06627717
# Training accuracy:  0.06618527
# Testing  accuracy:  0.71786320
# Direction accuracy: 93.75%
# The min of acquiring = 0.16216274, post_mean = 0.78724097, post_std = 0.62507823, index 38555
# NN 30-24-24-21: total params: 2821
# Epoch [ 20000/100000], Loss: 0.18856913
# Epoch [ 40000/100000], Loss: 0.12986560
# Epoch [ 60000/100000], Loss: 0.10338757
# Epoch [ 80000/100000], Loss: 0.08643211
# Epoch [100000/100000], Loss: 0.07904160
# Training accuracy:  0.07791303
# Testing  accuracy:  1.19656789
# Direction accuracy: 92.90%
# The min of acquiring = 0.15685442, post_mean = 0.74449766, post_std = 0.58764324, index 44125
# NN 31-26-24-24: total params: 3066
# Epoch [ 20000/100000], Loss: 0.21744625
# Epoch [ 40000/100000], Loss: 0.16720162
# Epoch [ 60000/100000], Loss: 0.14537390
# Epoch [ 80000/100000], Loss: 0.13513267
# Epoch [100000/100000], Loss: 0.13849294
# Training accuracy:  0.11265300
# Testing  accuracy:  0.83068091
# Direction accuracy: 92.96%
# The min of acquiring = 0.16793361, post_mean = 0.30523884, post_std = 0.13730522, index 17435
# NN 24-24-19-15: total params: 2135
# Epoch [ 20000/100000], Loss: 0.25731334
# Epoch [ 40000/100000], Loss: 0.17389759
# Epoch [ 60000/100000], Loss: 0.14913523
# Epoch [ 80000/100000], Loss: 0.13515632
# Epoch [100000/100000], Loss: 0.11941473
# Training accuracy:  0.11933898
# Testing  accuracy:  0.66602331
# Direction accuracy: 93.33%
# The min of acquiring = 0.14910926, post_mean = 0.77472954, post_std = 0.62562028, index 34639
# NN 29-26-22-19: total params: 2730
# Epoch [ 20000/100000], Loss: 0.25574812
# Epoch [ 40000/100000], Loss: 0.17987412
# Epoch [ 60000/100000], Loss: 0.14793000
# Epoch [ 80000/100000], Loss: 0.12197968
# Epoch [100000/100000], Loss: 0.10631508
# Training accuracy:  0.10597352
# Testing  accuracy:  0.63140899
# Direction accuracy: 94.24%
# The min of acquiring = 0.16484503, post_mean = 0.77047225, post_std = 0.60562722, index 14809
# NN 23-23-16-16: total params: 1938
# Epoch [ 20000/100000], Loss: 0.26916972
# Epoch [ 40000/100000], Loss: 0.21537083
# Epoch [ 60000/100000], Loss: 0.18616894
# Epoch [ 80000/100000], Loss: 0.16667123
# Epoch [100000/100000], Loss: 0.15460472
# Training accuracy:  0.15459317
# Testing  accuracy:  0.85168266
# Direction accuracy: 92.04%
# The min of acquiring = 0.15168642, post_mean = 0.71136403, post_std = 0.55967761, index 34665
# NN 29-26-23-23: total params: 2876
# Epoch [ 20000/100000], Loss: 0.26602653
# Epoch [ 40000/100000], Loss: 0.19664313
# Epoch [ 60000/100000], Loss: 0.16422759
# Epoch [ 80000/100000], Loss: 0.14266250
# Epoch [100000/100000], Loss: 0.12941074
# Training accuracy:  0.12867332
# Testing  accuracy:  0.89514410
# Direction accuracy: 93.08%
# The min of acquiring = 0.16413297, post_mean = 0.72837965, post_std = 0.56424668, index 30234
# NN 28-25-21-20: total params: 2600
# Epoch [ 20000/100000], Loss: 0.21524324
# Epoch [ 40000/100000], Loss: 0.15690748
# Epoch [ 60000/100000], Loss: 0.12511164
# Epoch [ 80000/100000], Loss: 0.10601919
# Epoch [100000/100000], Loss: 0.10141575
# Training accuracy:  0.09617041
# Testing  accuracy:  0.81754005
# Direction accuracy: 93.88%
# The min of acquiring = 0.17127078, post_mean = 0.75996732, post_std = 0.58869654, index 34388
# NN 29-25-25-24: total params: 2948
# Epoch [ 20000/100000], Loss: 0.25990203
# Epoch [ 40000/100000], Loss: 0.20197567
# Epoch [ 60000/100000], Loss: 0.16659196
# Epoch [ 80000/100000], Loss: 0.13762838
# Epoch [100000/100000], Loss: 0.12543181
# Training accuracy:  0.11814668
# Testing  accuracy:  0.64153540
# Direction accuracy: 93.88%
# The min of acquiring = 0.17222288, post_mean = 0.67902224, post_std = 0.50679936, index 38558
# NN 30-24-24-24: total params: 2899
# Epoch [ 20000/100000], Loss: 0.24608178
# Epoch [ 40000/100000], Loss: 0.15777411
# Epoch [ 60000/100000], Loss: 0.12501171
# Epoch [ 80000/100000], Loss: 0.10762492
# Epoch [100000/100000], Loss: 0.09413893
# Training accuracy:  0.09260777
# Testing  accuracy:  1.10806894
# Direction accuracy: 93.02%
# The min of acquiring = 0.15294385, post_mean = 0.71584846, post_std = 0.56290461, index 39231
# NN 30-26-26-23: total params: 3083
# Epoch [ 20000/100000], Loss: 0.18873274
# Epoch [ 40000/100000], Loss: 0.13893822
# Epoch [ 60000/100000], Loss: 0.10845922
# Epoch [ 80000/100000], Loss: 0.08939414
# Epoch [100000/100000], Loss: 0.07654286
# Training accuracy:  0.07654286
# Testing  accuracy:  0.70896411
# Direction accuracy: 94.06%
# The min of acquiring = 0.18049788, post_mean = 0.61763208, post_std = 0.43713420, index 34991
# NN 29-27-22-20: total params: 2806
# Epoch [ 20000/100000], Loss: 0.19847821
# Epoch [ 40000/100000], Loss: 0.14562073
# Epoch [ 60000/100000], Loss: 0.11778788
# Epoch [ 80000/100000], Loss: 0.09626064
# Epoch [100000/100000], Loss: 0.08291629
# Training accuracy:  0.07940975
# Testing  accuracy:  0.49421313
# Direction accuracy: 94.61%
# The min of acquiring = 0.19064274, post_mean = 0.70015403, post_std = 0.50951129, index 31245
# NN 28-28-19-16: total params: 2568
# Epoch [ 20000/100000], Loss: 0.14118427
# Epoch [ 40000/100000], Loss: 0.09328926
# Epoch [ 60000/100000], Loss: 0.07711130
# Epoch [ 80000/100000], Loss: 0.06843081
# Epoch [100000/100000], Loss: 0.06293277
# Training accuracy:  0.06288820
# Testing  accuracy:  0.84731716
# Direction accuracy: 93.20%
# The min of acquiring = 0.10545643, post_mean = 0.55662657, post_std = 0.45117014, index 40266
# NN 30-29-22-17: total params: 2898
# Epoch [ 20000/100000], Loss: 0.15294188
# Epoch [ 40000/100000], Loss: 0.10667431
# Epoch [ 60000/100000], Loss: 0.08766961
# Epoch [ 80000/100000], Loss: 0.08002463
# Epoch [100000/100000], Loss: 0.07255930
# Training accuracy:  0.07254028
# Testing  accuracy:  1.18178654
# Direction accuracy: 93.14%
# The min of acquiring = -0.10584097, post_mean = 0.39548881, post_std = 0.50132978, index 39527
# NN 30-27-24-17: total params: 2882
# Epoch [ 20000/100000], Loss: 0.21398808
# Epoch [ 40000/100000], Loss: 0.15867853
# Epoch [ 60000/100000], Loss: 0.12926134
# Epoch [ 80000/100000], Loss: 0.11433223
# Epoch [100000/100000], Loss: 0.10185625
# Training accuracy:  0.10047159
# Testing  accuracy:  0.81163764
# Direction accuracy: 93.39%
# The min of acquiring = 0.02286636, post_mean = 0.49468575, post_std = 0.47181939, index 46101
# NN 31-31-23-17: total params: 3115
# Epoch [ 20000/100000], Loss: 0.18143359
# Epoch [ 40000/100000], Loss: 0.13046287
# Epoch [ 60000/100000], Loss: 0.10020119
# Epoch [ 80000/100000], Loss: 0.08978001
# Epoch [100000/100000], Loss: 0.07387223
# Training accuracy:  0.07360303
# Testing  accuracy:  0.57499629
# Direction accuracy: 93.88%
# The min of acquiring = 0.07169137, post_mean = 0.64915173, post_std = 0.57746036, index 50143
# NN 32-28-20-16: total params: 2849
# Epoch [ 20000/100000], Loss: 0.18744759
# Epoch [ 40000/100000], Loss: 0.13667591
# Epoch [ 60000/100000], Loss: 0.11657124
# Epoch [ 80000/100000], Loss: 0.09669236
# Epoch [100000/100000], Loss: 0.08444878
# Training accuracy:  0.08131238
# Testing  accuracy:  0.69959158
# Direction accuracy: 93.57%
# The min of acquiring = 0.10832048, post_mean = 0.44366109, post_std = 0.33534061, index 35732
# NN 29-29-20-18: total params: 2766
# Epoch [ 20000/100000], Loss: 0.17417334
# Epoch [ 40000/100000], Loss: 0.11496466
# Epoch [ 60000/100000], Loss: 0.10068364
# Epoch [ 80000/100000], Loss: 0.09210253
# Epoch [100000/100000], Loss: 0.07737178
# Training accuracy:  0.07736992
# Testing  accuracy:  0.96201676
# Direction accuracy: 93.57%
# The min of acquiring = 0.06750970, post_mean = 0.60720812, post_std = 0.53969842, index 45148
# NN 31-29-19-17: total params: 2817
# Epoch [ 20000/100000], Loss: 0.19279930
# Epoch [ 40000/100000], Loss: 0.13953403
# Epoch [ 60000/100000], Loss: 0.11419518
# Epoch [ 80000/100000], Loss: 0.10243591
# Epoch [100000/100000], Loss: 0.08090547
# Training accuracy:  0.08065981
# Testing  accuracy:  0.79030037
# Direction accuracy: 92.96%
# The min of acquiring = 0.13692808, post_mean = 0.66310469, post_std = 0.52617661, index 35011
# NN 29-27-23-18: total params: 2804
# Epoch [ 20000/100000], Loss: 0.26509288
# Epoch [ 40000/100000], Loss: 0.19118826
# Epoch [ 60000/100000], Loss: 0.14413409
# Epoch [ 80000/100000], Loss: 0.11827083
# Epoch [100000/100000], Loss: 0.10334377
# Training accuracy:  0.10309977
# Testing  accuracy:  0.52385902
# Direction accuracy: 94.37%
# The min of acquiring = 0.13602648, post_mean = 0.63005850, post_std = 0.49403202, index 39506
# NN 30-27-23-19: total params: 2887
# Epoch [ 20000/100000], Loss: 0.19956382
# Epoch [ 40000/100000], Loss: 0.15466771
# Epoch [ 60000/100000], Loss: 0.12104921
# Epoch [ 80000/100000], Loss: 0.10077621
# Epoch [100000/100000], Loss: 0.08960486
# Training accuracy:  0.08948353
# Testing  accuracy:  1.07360542
# Direction accuracy: 92.41%
# The min of acquiring = 0.06326233, post_mean = 0.61747358, post_std = 0.55421126, index 31328
# NN 28-28-23-17: total params: 2773
# Epoch [ 20000/100000], Loss: 0.19463389
# Epoch [ 40000/100000], Loss: 0.13464737
# Epoch [ 60000/100000], Loss: 0.11056455
# Epoch [ 80000/100000], Loss: 0.09457356
# Epoch [100000/100000], Loss: 0.08407710
# Training accuracy:  0.08380612
# Testing  accuracy:  0.86065847
# Direction accuracy: 93.39%
# The min of acquiring = 0.12346208, post_mean = 0.57500035, post_std = 0.45153827, index 30952
# NN 28-27-23-19: total params: 2771
# Epoch [ 20000/100000], Loss: 0.14554010
# Epoch [ 40000/100000], Loss: 0.10802298
# Epoch [ 60000/100000], Loss: 0.08906808
# Epoch [ 80000/100000], Loss: 0.07914025
# Epoch [100000/100000], Loss: 0.07444711
# Training accuracy:  0.07158884
# Testing  accuracy:  0.93777788
# Direction accuracy: 93.75%
# The min of acquiring = 0.10882106, post_mean = 0.67406691, post_std = 0.56524585, index 34988
# NN 29-27-22-17: total params: 2734
# Epoch [ 20000/100000], Loss: 0.27553439
# Epoch [ 40000/100000], Loss: 0.21799368
# Epoch [ 60000/100000], Loss: 0.18579116
# Epoch [ 80000/100000], Loss: 0.15847452
# Epoch [100000/100000], Loss: 0.14151028
# Training accuracy:  0.13955538
# Testing  accuracy:  0.73586696
# Direction accuracy: 92.96%
# The min of acquiring = 0.12329662, post_mean = 0.55732735, post_std = 0.43403073, index 40720
# NN 30-30-23-17: total params: 2999
# Epoch [ 20000/100000], Loss: 0.15194990
# Epoch [ 40000/100000], Loss: 0.10660475
# Epoch [ 60000/100000], Loss: 0.08394954
# Epoch [ 80000/100000], Loss: 0.07302654
# Epoch [100000/100000], Loss: 0.06309041
# Training accuracy:  0.06295563
# Testing  accuracy:  0.55673933
# Direction accuracy: 94.55%
# The min of acquiring = 0.13229440, post_mean = 0.67956802, post_std = 0.54727362, index 30581
# NN 28-26-22-21: total params: 2721
# Epoch [ 20000/100000], Loss: 0.22232617
# Epoch [ 40000/100000], Loss: 0.16167748
# Epoch [ 60000/100000], Loss: 0.12904082
# Epoch [ 80000/100000], Loss: 0.11481983
# Epoch [100000/100000], Loss: 0.11020653
# Training accuracy:  0.10120582
# Testing  accuracy:  0.58658803
# Direction accuracy: 93.57%
# The min of acquiring = 0.13225748, post_mean = 0.64304994, post_std = 0.51079245, index 34971
# NN 29-27-21-21: total params: 2781
# Epoch [ 20000/100000], Loss: 0.17650972
# Epoch [ 40000/100000], Loss: 0.12060958
# Epoch [ 60000/100000], Loss: 0.09356101
# Epoch [ 80000/100000], Loss: 0.07949647
# Epoch [100000/100000], Loss: 0.06812494
# Training accuracy:  0.06804097
# Testing  accuracy:  0.52321982
# Direction accuracy: 94.61%
# The min of acquiring = 0.14007078, post_mean = 0.62211588, post_std = 0.48204511, index 50566
# NN 32-29-21-15: total params: 2925
# Epoch [ 20000/100000], Loss: 0.20338283
# Epoch [ 40000/100000], Loss: 0.14038676
# Epoch [ 60000/100000], Loss: 0.12383252
# Epoch [ 80000/100000], Loss: 0.09852770
# Epoch [100000/100000], Loss: 0.08597746
# Training accuracy:  0.08587086
# Testing  accuracy:  0.77714658
# Direction accuracy: 94.30%
# The min of acquiring = 0.12370740, post_mean = 0.62294597, post_std = 0.49923857, index 30910
# NN 28-27-21-20: total params: 2700
# Epoch [ 20000/100000], Loss: 0.29716173
# Epoch [ 40000/100000], Loss: 0.21477203
# Epoch [ 60000/100000], Loss: 0.18167236
# Epoch [ 80000/100000], Loss: 0.15561132
# Epoch [100000/100000], Loss: 0.13802983
# ...
# Training accuracy:  0.07547595
# Testing  accuracy:  0.70632440
# Direction accuracy: 93.33%
# The min of acquiring = 0.27788915, post_mean = 0.69657152, post_std = 0.41868238, index 35823
# NN 29-29-24-23: total params: 3088
# Epoch [ 20000/100000], Loss: 0.21689215
# Epoch [ 40000/100000], Loss: 0.15491104
# Epoch [ 60000/100000], Loss: 0.11887385
# Epoch [ 80000/100000], Loss: 0.09829369
# Epoch [100000/100000], Loss: 0.08567704
# Training accuracy:  0.08530026
# Testing  accuracy:  0.77478975
# Direction accuracy: 93.75%
# The min of acquiring = 0.28846938, post_mean = 0.61914886, post_std = 0.33067948, index 30582
# NN 28-26-22-22: total params: 2745
# Epoch [ 20000/100000], Loss: 0.27568582
# Epoch [ 40000/100000], Loss: 0.22689438
# Epoch [ 60000/100000], Loss: 0.17523186
# Epoch [ 80000/100000], Loss: 0.14989172
# Epoch [100000/100000], Loss: 0.13276009
# Training accuracy:  0.13193987
# Testing  accuracy:  0.81142449
# Direction accuracy: 93.45%
# The min of acquiring = 0.28983342, post_mean = 0.63907863, post_std = 0.34924521, index 39509
# NN 30-27-23-22: total params: 2962
# Epoch [ 20000/100000], Loss: 0.16524151
# Epoch [ 40000/100000], Loss: 0.11653965
# Epoch [ 60000/100000], Loss: 0.09412963
# Epoch [ 80000/100000], Loss: 0.08380040
# Epoch [100000/100000], Loss: 0.07185174
# Training accuracy:  0.07159534
# Testing  accuracy:  0.68801844
# Direction accuracy: 93.45%
# The min of acquiring = 0.30151433, post_mean = 0.68386362, post_std = 0.38234929, index 34016
# NN 29-24-22-21: total params: 2674
# Epoch [ 20000/100000], Loss: 0.25664911
# Epoch [ 40000/100000], Loss: 0.17769967
# Epoch [ 60000/100000], Loss: 0.15224567
# Epoch [ 80000/100000], Loss: 0.11849413
# Epoch [100000/100000], Loss: 0.10151970
# Training accuracy:  0.10138924
# Testing  accuracy:  0.67908978
# Direction accuracy: 93.26%
# The min of acquiring = 0.30907698, post_mean = 0.77098702, post_std = 0.46191005, index 27197
# NN 27-27-18-18: total params: 2458
# Epoch [ 20000/100000], Loss: 0.18744099
# Epoch [ 40000/100000], Loss: 0.13501145
# Epoch [ 60000/100000], Loss: 0.11486802
# Epoch [ 80000/100000], Loss: 0.10309770
# Epoch [100000/100000], Loss: 0.09645457
# Training accuracy:  0.09521016
# Testing  accuracy:  0.99378622
# Direction accuracy: 93.69%
# The min of acquiring = 0.31988850, post_mean = 0.76033456, post_std = 0.44044606, index 35695
# NN 29-29-18-18: total params: 2670
# Epoch [ 20000/100000], Loss: 0.27274320
# Epoch [ 40000/100000], Loss: 0.18147811
# Epoch [ 60000/100000], Loss: 0.14484052
# Epoch [ 80000/100000], Loss: 0.12077396
# Epoch [100000/100000], Loss: 0.10329588
# Training accuracy:  0.10318696
# Testing  accuracy:  0.61178011
# Direction accuracy: 94.12%
# The min of acquiring = 0.30152617, post_mean = 0.73738985, post_std = 0.43586368, index 35288
# NN 29-28-18-17: total params: 2602
# Epoch [ 20000/100000], Loss: 0.18140060
# Epoch [ 40000/100000], Loss: 0.11496015
# Epoch [ 60000/100000], Loss: 0.09161600
# Epoch [ 80000/100000], Loss: 0.07313238
# Epoch [100000/100000], Loss: 0.06478114
# Training accuracy:  0.06467756
# Testing  accuracy:  0.69416153
# Direction accuracy: 94.73%
# The min of acquiring = 0.29331424, post_mean = 0.60229920, post_std = 0.30898496, index 35799
# NN 29-29-23-22: total params: 3010
# Epoch [ 20000/100000], Loss: 0.19062513
# Epoch [ 40000/100000], Loss: 0.13893990
# Epoch [ 60000/100000], Loss: 0.11163542
# Epoch [ 80000/100000], Loss: 0.09096125
# Epoch [100000/100000], Loss: 0.07647854
# Training accuracy:  0.07609735
# Testing  accuracy:  0.85936952
# Direction accuracy: 93.63%
# The min of acquiring = 0.31128975, post_mean = 0.75090730, post_std = 0.43961755, index 35677
# NN 29-29-17-17: total params: 2603
# Epoch [ 20000/100000], Loss: 0.19812188
# Epoch [ 40000/100000], Loss: 0.15040584
# Epoch [ 60000/100000], Loss: 0.11938396
# Epoch [ 80000/100000], Loss: 0.10370389
# Epoch [100000/100000], Loss: 0.09456301
# Training accuracy:  0.09298940
# Testing  accuracy:  0.64939654
# Direction accuracy: 93.57%
# The min of acquiring = 0.31633377, post_mean = 0.68738297, post_std = 0.37104920, index 46100
# NN 31-31-23-16: total params: 3090
# Epoch [ 20000/100000], Loss: 0.17231168
# Epoch [ 40000/100000], Loss: 0.12442036
# Epoch [ 60000/100000], Loss: 0.09576597
# Epoch [ 80000/100000], Loss: 0.07830522
# Epoch [100000/100000], Loss: 0.06694372
# Training accuracy:  0.06651915
# Testing  accuracy:  0.75810146
# Direction accuracy: 93.94%
# The min of acquiring = 0.32193646, post_mean = 0.62134360, post_std = 0.29940714, index 40225
# NN 30-29-20-17: total params: 2804
# Epoch [ 20000/100000], Loss: 0.19030729
# Epoch [ 40000/100000], Loss: 0.12703001
# Epoch [ 60000/100000], Loss: 0.10635635
# Epoch [ 80000/100000], Loss: 0.08561483
# Epoch [100000/100000], Loss: 0.07479130
# Training accuracy:  0.07294058
# Testing  accuracy:  0.63321507
# Direction accuracy: 93.45%
# The min of acquiring = 0.32313203, post_mean = 0.77198781, post_std = 0.44885579, index 56339
# NN 33-29-20-16: total params: 2962
# Epoch [ 20000/100000], Loss: 0.14455731
# Epoch [ 40000/100000], Loss: 0.09843427
# Epoch [ 60000/100000], Loss: 0.08024117
# Epoch [ 80000/100000], Loss: 0.07263104
# Epoch [100000/100000], Loss: 0.06206958
# Training accuracy:  0.06140276
# Testing  accuracy:  0.77833015
# Direction accuracy: 93.94%
# The min of acquiring = 0.32511693, post_mean = 0.70250875, post_std = 0.37739182, index 20267
# NN 25-25-15-13: total params: 2037
# Epoch [ 20000/100000], Loss: 0.19875228
# Epoch [ 40000/100000], Loss: 0.15216760
# Epoch [ 60000/100000], Loss: 0.12414489
# Epoch [ 80000/100000], Loss: 0.11155188
# Epoch [100000/100000], Loss: 0.10539300
# Training accuracy:  0.10539300
# Testing  accuracy:  1.03530908
# Direction accuracy: 92.77%
# The min of acquiring = 0.31638458, post_mean = 0.56661908, post_std = 0.25023450, index 20035
# NN 25-24-19-15: total params: 2190
# Epoch [ 20000/100000], Loss: 0.30011818
# Epoch [ 40000/100000], Loss: 0.22285885
# Epoch [ 60000/100000], Loss: 0.17881896
# Epoch [ 80000/100000], Loss: 0.14908791
# Epoch [100000/100000], Loss: 0.12948103
# Training accuracy:  0.12919465
# Testing  accuracy:  0.70584130
# Direction accuracy: 93.39%
# The min of acquiring = 0.29648119, post_mean = 0.74005201, post_std = 0.44357083, index 20056
# NN 25-24-20-17: total params: 2274
# Epoch [ 20000/100000], Loss: 0.25256455
# Epoch [ 40000/100000], Loss: 0.17219152
# Epoch [ 60000/100000], Loss: 0.13828509
# Epoch [ 80000/100000], Loss: 0.11902862
# Epoch [100000/100000], Loss: 0.10904492
# Training accuracy:  0.10698371
# Testing  accuracy:  0.78315330
# Direction accuracy: 93.75%
# The min of acquiring = 0.31345583, post_mean = 0.71060079, post_std = 0.39714496, index 22980
# NN 26-24-20-16: total params: 2307
# Epoch [ 20000/100000], Loss: 0.32842293
# Epoch [ 40000/100000], Loss: 0.24527395
# Epoch [ 60000/100000], Loss: 0.19401491
# Epoch [ 80000/100000], Loss: 0.15754960
# Epoch [100000/100000], Loss: 0.13427730
# Training accuracy:  0.13386315
# Testing  accuracy:  0.64922315
# Direction accuracy: 94.18%
# The min of acquiring = 0.31954168, post_mean = 0.76719969, post_std = 0.44765801, index 19706
# NN 25-23-16-13: total params: 1992
# Epoch [ 20000/100000], Loss: 0.34895661
# Epoch [ 40000/100000], Loss: 0.26700661
# Epoch [ 60000/100000], Loss: 0.23280634
# Epoch [ 80000/100000], Loss: 0.19741412
# Epoch [100000/100000], Loss: 0.17838022
# Training accuracy:  0.17835845
# Testing  accuracy:  0.74605179
# Direction accuracy: 92.96%
# The min of acquiring = 0.31306892, post_mean = 0.77267842, post_std = 0.45960950, index 17090
# NN 24-23-15-12: total params: 1884
# Epoch [ 20000/100000], Loss: 0.18644081
# Epoch [ 40000/100000], Loss: 0.14908993
# Epoch [ 60000/100000], Loss: 0.13089751
# Epoch [ 80000/100000], Loss: 0.12173678
# Epoch [100000/100000], Loss: 0.11655531
# Training accuracy:  0.11641514
# Testing  accuracy:  1.42193711
# Direction accuracy: 92.53%
# The min of acquiring = 0.32423031, post_mean = 0.74546289, post_std = 0.42123258, index 20355
# NN 25-25-20-16: total params: 2298
# Epoch [ 20000/100000], Loss: 0.29574311
# Epoch [ 40000/100000], Loss: 0.21767141
# Epoch [ 60000/100000], Loss: 0.18226497
# Epoch [ 80000/100000], Loss: 0.15869203
# Epoch [100000/100000], Loss: 0.14735757
# Training accuracy:  0.14281963
# Testing  accuracy:  0.63583547
# Direction accuracy: 94.30%
# The min of acquiring = 0.32538036, post_mean = 0.75877111, post_std = 0.43339075, index 20374
# NN 25-25-21-15: total params: 2317
# Epoch [ 20000/100000], Loss: 0.22802892
# Epoch [ 40000/100000], Loss: 0.15810324
# Epoch [ 60000/100000], Loss: 0.12001584
# Epoch [ 80000/100000], Loss: 0.10618539
# Epoch [100000/100000], Loss: 0.08996935
# Training accuracy:  0.08977294
# Testing  accuracy:  0.59394336
# Direction accuracy: 93.69%
# The min of acquiring = 0.30645328, post_mean = 0.71529685, post_std = 0.40884357, index 20075
# NN 25-24-21-16: total params: 2293
# Epoch [ 20000/100000], Loss: 0.22821505
# Epoch [ 40000/100000], Loss: 0.15633504
# Epoch [ 60000/100000], Loss: 0.12589133
# Epoch [ 80000/100000], Loss: 0.10846511
# Epoch [100000/100000], Loss: 0.10005875
# Training accuracy:  0.09749191
# Testing  accuracy:  0.68129063
# Direction accuracy: 93.94%
# The min of acquiring = 0.32816856, post_mean = 0.75855554, post_std = 0.43038698, index 20095
# NN 25-24-22-15: total params: 2310
# Epoch [ 20000/100000], Loss: 0.31272057
# Epoch [ 40000/100000], Loss: 0.22792330
# Epoch [ 60000/100000], Loss: 0.17408067
# Epoch [ 80000/100000], Loss: 0.14521419
# Epoch [100000/100000], Loss: 0.12767498
# Training accuracy:  0.12685829
# Testing  accuracy:  0.83833629
# Direction accuracy: 93.69%
# The min of acquiring = 0.31992833, post_mean = 0.74270239, post_std = 0.42277405, index 23300
# NN 26-25-21-16: total params: 2396
# Epoch [ 20000/100000], Loss: 0.23778696
# Epoch [ 40000/100000], Loss: 0.16712469
# Epoch [ 60000/100000], Loss: 0.13114418
# Epoch [ 80000/100000], Loss: 0.11466194
# Epoch [100000/100000], Loss: 0.10072474
# Training accuracy:  0.10071122
# Testing  accuracy:  0.62092054
# Direction accuracy: 94.00%
# The min of acquiring = 0.33209389, post_mean = 0.69983517, post_std = 0.36774128, index 20402
# NN 25-25-22-22: total params: 2526
# Epoch [ 20000/100000], Loss: 0.27760336
# Epoch [ 40000/100000], Loss: 0.20718400
# Epoch [ 60000/100000], Loss: 0.17095441
# Epoch [ 80000/100000], Loss: 0.14995979
# Epoch [100000/100000], Loss: 0.12530561
# Training accuracy:  0.12528557
# Testing  accuracy:  0.59971410
# Direction accuracy: 94.18%
# The min of acquiring = 0.32678099, post_mean = 0.75297954, post_std = 0.42619855, index 31211
# NN 28-28-17-17: total params: 2497
# Epoch [ 20000/100000], Loss: 0.15502442
# Epoch [ 40000/100000], Loss: 0.11188978
# Epoch [ 60000/100000], Loss: 0.09555687
# Epoch [ 80000/100000], Loss: 0.08543628
# Epoch [100000/100000], Loss: 0.08014245
# Training accuracy:  0.07935707
# Testing  accuracy:  0.70951331
# Direction accuracy: 94.24%
# The min of acquiring = 0.33028170, post_mean = 0.77289031, post_std = 0.44260861, index 20124
# NN 25-24-23-22: total params: 2525
# Epoch [ 20000/100000], Loss: 0.29337591
# Epoch [ 40000/100000], Loss: 0.20208165
# Epoch [ 60000/100000], Loss: 0.16257933
# Epoch [ 80000/100000], Loss: 0.14067017
# Epoch [100000/100000], Loss: 0.12612669
# Training accuracy:  0.12607324
# Testing  accuracy:  1.08470416
# Direction accuracy: 93.39%
# The min of acquiring = 0.33462970, post_mean = 0.76009732, post_std = 0.42546762, index 39233
# NN 30-26-26-25: total params: 3139
# Epoch [ 20000/100000], Loss: 0.17529130
# Epoch [ 40000/100000], Loss: 0.11353855
# Epoch [ 60000/100000], Loss: 0.09019426
# Epoch [ 80000/100000], Loss: 0.07484923
# Epoch [100000/100000], Loss: 0.06555535
# Training accuracy:  0.06553199
# Testing  accuracy:  0.71181637
# Direction accuracy: 94.18%
# The min of acquiring = 0.32832641, post_mean = 0.61477638, post_std = 0.28644997, index 20375
# NN 25-25-21-16: total params: 2340
# Epoch [ 20000/100000], Loss: 0.21207127
# Epoch [ 40000/100000], Loss: 0.14510180
# Epoch [ 60000/100000], Loss: 0.11701659
# Epoch [ 80000/100000], Loss: 0.10103664
# Epoch [100000/100000], Loss: 0.08954133
# Training accuracy:  0.08951839
# Testing  accuracy:  0.75181150
# Direction accuracy: 93.63%
# The min of acquiring = 0.30967721, post_mean = 0.63186781, post_std = 0.32219061, index 23299
# NN 26-25-21-15: total params: 2373
# Epoch [ 20000/100000], Loss: 0.22262552
# Epoch [ 40000/100000], Loss: 0.15425970
# Epoch [ 60000/100000], Loss: 0.12169378
# Epoch [ 80000/100000], Loss: 0.10484172
# Epoch [100000/100000], Loss: 0.09271909
# Training accuracy:  0.09267578
# Testing  accuracy:  0.89588588
# Direction accuracy: 94.12%
# The min of acquiring = 0.31547748, post_mean = 0.67516117, post_std = 0.35968369, index 23301
# NN 26-25-21-17: total params: 2419
# Epoch [ 20000/100000], Loss: 0.25504318
# Epoch [ 40000/100000], Loss: 0.17952263
# Epoch [ 60000/100000], Loss: 0.14262944
# Epoch [ 80000/100000], Loss: 0.11901988
# Epoch [100000/100000], Loss: 0.11092037
# Training accuracy:  0.10312778
# Testing  accuracy:  0.65629399
# Direction accuracy: 94.37%
# The min of acquiring = 0.31714904, post_mean = 0.73185145, post_std = 0.41470241, index 17474
# NN 24-24-21-15: total params: 2215
# Epoch [ 20000/100000], Loss: 0.31752482
# Epoch [ 40000/100000], Loss: 0.23572785
# Epoch [ 60000/100000], Loss: 0.19761887
# Epoch [ 80000/100000], Loss: 0.17417455
# Epoch [100000/100000], Loss: 0.15205957
# Training accuracy:  0.15140653
# Testing  accuracy:  0.77879637
# Direction accuracy: 93.08%
# The min of acquiring = 0.32683767, post_mean = 0.71773539, post_std = 0.39089772, index 23261
# NN 26-25-19-16: total params: 2312
# Epoch [ 20000/100000], Loss: 0.18255216
# Epoch [ 40000/100000], Loss: 0.13237894
# Epoch [ 60000/100000], Loss: 0.10965287
# Epoch [ 80000/100000], Loss: 0.09739294
# Epoch [100000/100000], Loss: 0.09016748
# Training accuracy:  0.08990741
# Testing  accuracy:  0.70553499
# Direction accuracy: 93.88%
# The min of acquiring = 0.33260754, post_mean = 0.76288035, post_std = 0.43027281, index 23022
# NN 26-24-22-17: total params: 2413
# Epoch [ 20000/100000], Loss: 0.24619025
# Epoch [ 40000/100000], Loss: 0.17279653
# Epoch [ 60000/100000], Loss: 0.14040788
# Epoch [ 80000/100000], Loss: 0.12059667
# Epoch [100000/100000], Loss: 0.10624728
# Training accuracy:  0.10624728
# Testing  accuracy:  0.58631712
# Direction accuracy: 93.88%
# The min of acquiring = 0.31511789, post_mean = 0.75063606, post_std = 0.43551817, index 26297
# NN 27-24-22-16: total params: 2444
# Epoch [ 20000/100000], Loss: 0.26397893
# Epoch [ 40000/100000], Loss: 0.19559321
# Epoch [ 60000/100000], Loss: 0.15996945
# Epoch [ 80000/100000], Loss: 0.13886082
# Epoch [100000/100000], Loss: 0.13298464
# Training accuracy:  0.12576799
# Testing  accuracy:  0.79797411
# Direction accuracy: 93.69%
# The min of acquiring = 0.32119272, post_mean = 0.67122621, post_std = 0.35003349, index 23322
# NN 26-25-22-17: total params: 2462
# Epoch [ 20000/100000], Loss: 0.21002488
# Epoch [ 40000/100000], Loss: 0.13656114
# Epoch [ 60000/100000], Loss: 0.10541718
# Epoch [ 80000/100000], Loss: 0.09437979
# Epoch [100000/100000], Loss: 0.08514706
# Training accuracy:  0.08479036
# Testing  accuracy:  0.91490644
# Direction accuracy: 93.39%
# The min of acquiring = 0.26952664, post_mean = 0.64063719, post_std = 0.37111055, index 22746
# NN 26-23-22-17: total params: 2364
# Epoch [ 20000/100000], Loss: 0.26868600
# Epoch [ 40000/100000], Loss: 0.20221850
# Epoch [ 60000/100000], Loss: 0.16455126
# Epoch [ 80000/100000], Loss: 0.13720652
# Epoch [100000/100000], Loss: 0.12663431
# Training accuracy:  0.11915433
# Testing  accuracy:  0.70075935
# Direction accuracy: 93.51%
# The min of acquiring = 0.28067922, post_mean = 0.59392608, post_std = 0.31324686, index 23001
# NN 26-24-21-17: total params: 2371
# Epoch [ 20000/100000], Loss: 0.26946855
# Epoch [ 40000/100000], Loss: 0.21187305
# Epoch [ 60000/100000], Loss: 0.16934069
# Epoch [ 80000/100000], Loss: 0.14938176
# Epoch [100000/100000], Loss: 0.13209492
# Training accuracy:  0.13173340
# Testing  accuracy:  0.66454917
# Direction accuracy: 93.51%
# The min of acquiring = 0.33288937, post_mean = 0.74393013, post_std = 0.41104076, index 23606
# NN 26-26-20-17: total params: 2423
# Epoch [ 20000/100000], Loss: 0.20781495
# Epoch [ 40000/100000], Loss: 0.14534853
# Epoch [ 60000/100000], Loss: 0.12128473
# Epoch [ 80000/100000], Loss: 0.11453463
# Epoch [100000/100000], Loss: 0.09076109
# Training accuracy:  0.09074821
# Testing  accuracy:  0.80896789
# Direction accuracy: 93.39%

# %%
df = pd.DataFrame(hyperparams)
df.columns=['x1','x2','x3','x4']
df['TrainAcc'] = error_rates
df['TestAcc'] = accuracy_rates
df['DirAcc'] = dir_accuracy
# Sort the DataFrame in reverse order by the "Accuracy" column
df = df.sort_values(by='TestAcc', ascending=True)

# %%
df.head(10)
# Out:
#      x1  x2  x3  x4  TrainAcc   TestAcc     DirAcc
# 60   30  30  22  17  0.095148  0.488462  94.182486
# 41   24  24  21  12  0.111062  0.489500  94.672382
# 100  29  27  22  20  0.079410  0.494213  94.611145
# 149  26  26  22  21  0.112939  0.503866  94.427434
# 173  30  28  22  20  0.111859  0.505518  94.304960
# 211  29  29  23  23  0.105824  0.508156  94.182486
# 115  29  27  21  21  0.068041  0.523220  94.611145
# 108  29  27  23  18  0.103100  0.523859  94.366197
# 120  31  31  22  17  0.088129  0.539657  93.570116
# 113  30  30  23  17  0.062956  0.556739  94.549908

# %%
df.describe()
# Out:
#                x1          x2          x3          x4    TrainAcc     TestAcc  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    27.900794   25.928571   20.452381   17.551587    0.123772    0.834504
# std      3.141117    2.838771    3.002276    3.708679    0.377154    0.458629
# min      1.000000    1.000000    1.000000    1.000000    0.056081    0.488462
# 25%     26.000000   24.000000   19.000000   15.000000    0.082123    0.666219
# 50%     28.000000   26.000000   21.000000   17.000000    0.097525    0.769775
# 75%     30.000000   28.000000   22.000000   21.000000    0.114861    0.903833
# max     50.000000   31.000000   26.000000   25.000000    6.075071    7.290603
#
#            DirAcc
# count  252.000000
# mean    93.534881
# std      1.213130
# min     77.770974
# 25%     93.141457
# 50%     93.631353
# 75%     94.075321
# max     95.345989

# %%
df.to_excel('hyperparameters.xlsx')

# %%
# Check the evaluation of the best network
accuracy, error, model = evaluate([30,30,22,17], X_train, y_train, device, verbose=True)
# Out:
# NN 30-30-22-17: total params: 2951
# Epoch [ 20000/100000], Loss: 0.12997872
# Epoch [ 40000/100000], Loss: 0.08670329
# Epoch [ 60000/100000], Loss: 0.07215597
# Epoch [ 80000/100000], Loss: 0.06438527
# Epoch [100000/100000], Loss: 0.05819779
# Training accuracy:  0.05744401
# Testing  accuracy:  0.71489292

# %%
get_accuracy(model.to(device), X_test, y_test)
# Out:
# Direction accuracy: 93.75%
# 93.75382731169627

# %% [markdown]
# ### Conclusion
# The testing accuracy 0.7148 of 30-30-22-17 model is different from optimzation run (Accuracy was 0.488462). This is because of complexity of NN models which might not always converge to the same local minimum with the same accuracy. Therefore the best models table should be treated as a guidelines only. That's why I would like to take the average numbers of best 8 models for production NN instead of top performing model.

# %%
df.head(8).mean()
# Out:
# x1          28.250000
# x2          27.250000
# x3          22.000000
# x4          19.000000
# TrainAcc     0.098423
# TestAcc      0.504599
# DirAcc      94.419780
# dtype: float64

# %% [markdown]
# The production Neural Network will be with 28-27-22-19 neurons
